# %%
# %matplotlib notebook # helps with plotting live data in jupyter
import random
from itertools import count
from matplotlib import pyplot as plt 
import pandas as pd
from matplotlib.animation import FuncAnimation
# Out:
# Using matplotlib backend: nbAgg

# %%
# style of my plots:

plt.style.use('ggplot')

# %%
x_vals=[]

y_vals=[]

index= count()

# create a function for the animation:
def animate(i):
    x_vals.append(next(index))
    y_vals.append(random.randint(0,5))
    plt.cla() #clears out the axis after each plot
    plt.plot(x_vals, y_vals)
    

an= FuncAnimation(plt.gcf(),animate,interval=1000)  
#1st parameter: get current figure(plt.plot), 
#2: function we're running for our animation
#3: the interval for how often we want to run this function (2000= 2secs)



plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
############################ real world Data #######################################

# %%
data= pd.read_csv('live_data.csv') #This is live data from a python script that  continuously add rows

# %%
# Preview
data.head(10)
# Out:
#    x_value  total_1  total_2
# 0        0     1000     1000
# 1        1     1002     1002
# 2        2     1003     1008
# 3        3     1005     1014
# 4        4     1003     1020
# 5        5     1011     1024
# 6        6     1012     1023
# 7        7     1018     1025
# 8        8     1021     1025
# 9        9     1027     1029

# %%
# create a function for the animation:
def animate(i):
    
    data= pd.read_csv('live_data.csv') #This is live data from a python script that  continuously add rows
    
    x= data['x_value']

    y1= data['total_1']

    y2= data['total_2']
    
    plt.cla() #clears out the axis after each plot
    
    plt.plot(x, y1,label='y1')
    plt.plot(x, y2,label='y2')
    
    plt.legend(loc='upper right')
    
    

an= FuncAnimation(plt.gcf(),animate,interval=1000)  
#1st parameter: get current figure(plt.plot), 
#2: function we're running for our animation
#3: the interval for how often we want to run this function (2000= 2secs)



plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#it simultaneously plots the data as the python script adds more rows to the csv file
